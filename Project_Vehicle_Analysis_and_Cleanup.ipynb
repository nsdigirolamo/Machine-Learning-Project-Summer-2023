# %% [markdown]
# <a href="https://colab.research.google.com/github/nsdigirolamo/Machine-Learning-Project-Summer-2023/blob/main/Project_Vehicle_Analysis_and_Cleanup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mounted my google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# This implementation only looks at the scanning instances
import os
from collections import defaultdict
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df_vehicles = pd.read_csv('/content/drive/MyDrive/MachineLearning/vehicles.csv', header=0)
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-2-69af5a9392a9> in <cell line: 9>()
#       7 get_ipython().run_line_magic('matplotlib', 'inline')
#       8
# ----> 9 df_vehicles = pd.read_csv('/content/drive/MyDrive/MachineLearning/vehicles.csv', header=0)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
# dataset features
print(df_vehicles.columns)
# Out:
# Index(['id', 'url', 'region', 'region_url', 'price', 'year', 'manufacturer',
#        'model', 'condition', 'cylinders', 'fuel', 'odometer', 'title_status',
#        'transmission', 'VIN', 'drive', 'size', 'type', 'paint_color',
#        'image_url', 'description', 'county', 'state', 'lat', 'long',
#        'posting_date'],
#       dtype='object')

# %%
print(df_vehicles.head())
print(df_vehicles.info())
print(df_vehicles.describe())
print(df_vehicles.columns)
# Out:
#            id                                                url  \
# 0  7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1  7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2  7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3  7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4  7210384030  https://greensboro.craigslist.org/cto/d/trinit...
#
#                    region                         region_url  price  year  \
# 0                prescott    https://prescott.craigslist.org   6000   NaN
# 1            fayetteville       https://fayar.craigslist.org  11900   NaN
# 2            florida keys        https://keys.craigslist.org  21000   NaN
# 3  worcester / central MA   https://worcester.craigslist.org   1500   NaN
# 4              greensboro  https://greensboro.craigslist.org   4900   NaN
#
#   manufacturer model condition cylinders  ... size  type paint_color  \
# ...

# %%
# Check for missing values
print(df_vehicles.isnull().sum())

# Fill missing values with a specific value (e.g., 0)
# data_filled = df_vehicles.fillna(0)

# Drop rows with missing values
#data_dropped = df_vehicles.dropna()
# Out:
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year              1205
# manufacturer     17646
# model             5277
# condition       174104
# cylinders       177678
# fuel              3013
# odometer          4400
# title_status      8242
# transmission      2556
# VIN             161042
# drive           130567
# size            306361
# type             92858
# paint_color     130203
# image_url           68
# description         70
# county          426880
# state                0
# lat               6549
# long              6549
# posting_date        68
# dtype: int64

# %%
# Check for duplicated rows
print(df_vehicles.duplicated().sum())

# Drop duplicated rows
# data_unique = df_vehicles.drop_duplicates()
# Out:
# 0

# %%
# Convert a column to lowercase
# df_vehicles['column_name'] = df_vehicles['column_name'].str.lower()

# Replace specific values in a column
# df_vehicles['column_name'] = df_vehicles['column_name'].replace('old_value', 'new_value')

# Remove leading and trailing whitespaces
# df_vehicles['column_name'] = df_vehicles['column_name'].str.strip()

# Standardize categorical values
# df_vehicles['category'] = df_vehicles['category'].map({'A': 'Category A', 'B': 'Category B', 'C': 'Category C'})

# Convert a column to numeric type
# data['column_name'] = pd.to_numeric(data['column_name'])

# Convert a column to datetime type
# data['date_column'] = pd.to_datetime(data['date_column'])

# %%
# breakdown of manufacturer types
df_vehicle_man = df_vehicles['manufacturer'].value_counts()
print(df_vehicle_man)
df_vehicle_man.plot(kind='barh', figsize=(20,10), fontsize=11)
# Out:
# ford               70985
# chevrolet          55064
# toyota             34202
# honda              21269
# nissan             19067
# jeep               19014
# ram                18342
# gmc                16785
# bmw                14699
# dodge              13707
# mercedes-benz      11817
# hyundai            10338
# subaru              9495
# volkswagen          9345
# kia                 8457
# lexus               8200
# audi                7573
# cadillac            6953
# chrysler            6031
# acura               5978
# buick               5501
# mazda               5427
# infiniti            4802
# lincoln             4220
# volvo               3374
# mitsubishi          3292
# mini                2376
# pontiac             2288
# rover               2113
# jaguar              1946
# porsche             1384
# mercury             1184
# saturn              1090
# alfa-romeo           897
# tesla                868
# fiat                 792
# harley-davidson      153
# ...

# %%
# breakdown of manufacturer types
df_vehicle_year = df_vehicles['year'].value_counts()
print(df_vehicle_year)

df_vehicle_year.plot(kind='barh', figsize=(20,10), fontsize=5)
# Out:
# 2017.0    36420
# 2018.0    36369
# 2015.0    31538
# 2013.0    30794
# 2016.0    30434
#           ...
# 1943.0        1
# 1915.0        1
# 1902.0        1
# 1905.0        1
# 1909.0        1
# Name: year, Length: 114, dtype: int64
# <Axes: >

# %%
# Once the data is cleaned save a new file
# data_cleaned.to_csv('cleaned_vehicle_data.csv', index=False)
